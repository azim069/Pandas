# %% [markdown]
# # 🧨1. Handling Missing Data

# %%
import pandas as pd
import numpy as np

# %%
string_data = pd.Series(['A','Axe',np.nan,None])
string_data
# Out:
# 0       A
# 1     Axe
# 2     NaN
# 3    None
# dtype: object

# %%
#if we want to see 'Nan' value in boolean(True if there exist nan) 
#we have to call *isna()*
string_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
#Same case in float data type also
Float_data = pd.Series([10,2,30,None],dtype='float64')
Float_data
# Out:
# 0    10.0
# 1     2.0
# 2    30.0
# 3     NaN
# dtype: float64

# %%
#use of "isna" in float num also 
Float_data.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# #     🧲1.1 Filtering Out Missing Data

# %%
Data_1 = pd.Series([1,np.nan,None,10,20])
Data_1
# Out:
# 0     1.0
# 1     NaN
# 2     NaN
# 3    10.0
# 4    20.0
# dtype: float64

# %%
#if we want to delete 'Nan" value
#we have to use *dropna()*
Data_1.dropna()
# Out:
# 0     1.0
# 3    10.0
# 4    20.0
# dtype: float64

# %%
#Data in tabular form 
Data= pd.DataFrame([[1,2,None],[33,3,4],[10,1,None],[None,None,None]],columns=['a','b','c'])
Data
# Out:
#       a    b    c
# 0   1.0  2.0  NaN
# 1  33.0  3.0  4.0
# 2  10.0  1.0  NaN
# 3   NaN  NaN  NaN

# %%
Data.dropna()
# Out:
#       a    b    c
# 1  33.0  3.0  4.0

# %%
#how="all"  
#it delete that row where all value is 'Nan'
Data.dropna(how='all')
# Out:
#       a    b    c
# 0   1.0  2.0  NaN
# 1  33.0  3.0  4.0
# 2  10.0  1.0  NaN

# %%
Data['d'] = np.nan
Data
# Out:
#       a    b    c   d
# 0   1.0  2.0  NaN NaN
# 1  33.0  3.0  4.0 NaN
# 2  10.0  1.0  NaN NaN
# 3   NaN  NaN  NaN NaN

# %%
#axis="colums"
#we can delete data from colums 
Data.dropna(axis='columns',how='all')
# Out:
#       a    b    c
# 0   1.0  2.0  NaN
# 1  33.0  3.0  4.0
# 2  10.0  1.0  NaN
# 3   NaN  NaN  NaN

# %%
DF = pd.DataFrame(np.random.standard_normal((7,3)))
DF
# Out:
#           0         1         2
# 0 -0.284996 -0.246761 -1.589196
# 1 -0.796725  1.045306 -0.988231
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 4 -0.898134  0.104820  0.375416
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892

# %%
#convert into 'NaN' value 
#by using 'iloc' slicing
#(:2 is row) and (1 is column here)
DF.iloc[:2,1]=np.nan
DF.iloc[4:5,2]=np.nan
DF
# Out:
#           0         1         2
# 0 -0.284996       NaN -1.589196
# 1 -0.796725       NaN -0.988231
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 4 -0.898134  0.104820       NaN
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892

# %%
DF.dropna()
# Out:
#           0         1         2
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892

# %%
DF.dropna(thresh=3)
# Out:
#           0         1         2
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892

# %% [markdown]
# # 🧲1.2 Filling In Missing Data

# %%
#here we need statistics terms for fill the nan value 
DF.fillna(0)
# Out:
#           0         1         2
# 0 -0.284996  0.000000 -1.589196
# 1 -0.796725  0.000000 -0.988231
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 4 -0.898134  0.104820  0.000000
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892

# %%
DF.iloc[:2,1]=np.nan
DF.iloc[4:5,2]=np.nan
DF
# Out:
#           0         1         2
# 0 -0.284996       NaN -1.589196
# 1 -0.796725       NaN -0.988231
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 4 -0.898134  0.104820       NaN
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892

# %%
#fill the value by using dictionary for each columns 
#Check previous dataframe and this dataframe ,you can see the changes 
DF.fillna({1:3,2:1})
# Out:
#           0         1         2
# 0 -0.284996  3.000000 -1.589196
# 1 -0.796725  3.000000 -0.988231
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 4 -0.898134  0.104820  1.000000
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892

# %%
#method='ffill'
#this method is use to replace nan value by up row value 
#row 4 x column 2 ,you can see the change 
DF.fillna(method='ffill')
# Out:
#           0         1         2
# 0 -0.284996       NaN -1.589196
# 1 -0.796725       NaN -0.988231
# 2  0.863336  2.304859  1.607592
# 3  0.516101 -0.587420 -0.465126
# 4 -0.898134  0.104820 -0.465126
# 5 -1.298915  0.153315 -1.352704
# 6 -0.608071 -1.100281 -0.992892
